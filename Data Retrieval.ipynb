# %% [markdown]
# # Data Retrieval
#
# This notebook retreives data from 2021 to 2025.
#
# **TODO**: Organize the notebook

# %%
# !pip install pybaseball
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from pybaseball import statcast
from pathlib import Path

# %% [markdown]
# ### 2021 Season

# %%
season_2021 = statcast(start_dt="2021-04-01", end_dt="2021-10-03")
# Out:
# This is a large query, it may take a moment to complete
# /Users/samuelgartenstein/anaconda3/lib/python3.11/site-packages/pybaseball/statcast.py:50: UserWarning:
# That's a nice request you got there. It'd be a shame if something were to happen to it.
# We strongly recommend that you enable caching before running this. It's as simple as `pybaseball.cache.enable()`.
# Since the Statcast requests can take a *really* long time to run, if something were to happen, like: a disconnect;
# gremlins; computer repair by associates of Rudy Giuliani; electromagnetic interference from metal trash cans; etc.;
# you could lose a lot of progress. Enabling caching will allow you to immediately recover all the successful
# subqueries if that happens.
#   warnings.warn(_OVERSIZE_WARNING)
# ...

# %%
season_2021.head(10)
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 2886         FF 2021-10-03           92.3            1.4            6.8
# 3012         SL 2021-10-03           80.6            1.6           6.64
# 3163         CU 2021-10-03           75.5           1.46           6.88
# 3324         CU 2021-10-03           75.0           1.53           6.83
# 3489         FF 2021-10-03           91.2           1.49           6.66
# 3639         FF 2021-10-03           92.5           1.35           6.74
# 3842         SL 2021-10-03           80.3           1.81           6.55
# 3951         SL 2021-10-03           79.5           1.72           6.56
# 4118         FF 2021-10-03           91.8           1.39           6.75
# 2425         SI 2021-10-03           94.3           -1.2           6.05
#
#            player_name  batter  pitcher     events              description  \
# 2886       Smith, Will  596019   519293  field_out            hit_into_play
# ...

# %% [markdown]
# ### 2022 Season

# %%
season_2022 = statcast(start_dt="2022-04-07", end_dt="2022-10-05")
# Out:
# This is a large query, it may take a moment to complete
# /Users/samuelgartenstein/anaconda3/lib/python3.11/site-packages/pybaseball/statcast.py:50: UserWarning:
# That's a nice request you got there. It'd be a shame if something were to happen to it.
# We strongly recommend that you enable caching before running this. It's as simple as `pybaseball.cache.enable()`.
# Since the Statcast requests can take a *really* long time to run, if something were to happen, like: a disconnect;
# gremlins; computer repair by associates of Rudy Giuliani; electromagnetic interference from metal trash cans; etc.;
# you could lose a lot of progress. Enabling caching will allow you to immediately recover all the successful
# subqueries if that happens.
#   warnings.warn(_OVERSIZE_WARNING)
# ...

# %%
season_2022.head(10)
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 3269         CH 2022-10-05           80.8          -0.76           6.61
# 3305         FF 2022-10-05           97.7          -0.58            6.6
# 3485         CH 2022-10-05           84.9          -0.55           6.58
# 3623         FF 2022-10-05           97.2          -0.42            6.6
# 3777         SL 2022-10-05           86.2          -0.55           6.64
# 3924         FF 2022-10-05           97.5          -0.56           6.68
# 4041         CH 2022-10-05           84.9          -0.58           6.65
# 4225         FF 2022-10-05           98.2          -0.59           6.72
# 4368         CH 2022-10-05           83.8          -0.41           6.57
# 4524         FF 2022-10-05           96.7          -0.41           6.75
#
#        player_name  batter  pitcher     events      description  ...  \
# 3269  Baker, Bryan  624415   641329  field_out    hit_into_play  ...
# ...

# %% [markdown]
# ### 2023 Season

# %%
season_2023 = statcast(start_dt="2023-03-30", end_dt="2023-10-01")
# Out:
# This is a large query, it may take a moment to complete
# /Users/samuelgartenstein/anaconda3/lib/python3.11/site-packages/pybaseball/statcast.py:50: UserWarning:
# That's a nice request you got there. It'd be a shame if something were to happen to it.
# We strongly recommend that you enable caching before running this. It's as simple as `pybaseball.cache.enable()`.
# Since the Statcast requests can take a *really* long time to run, if something were to happen, like: a disconnect;
# gremlins; computer repair by associates of Rudy Giuliani; electromagnetic interference from metal trash cans; etc.;
# you could lose a lot of progress. Enabling caching will allow you to immediately recover all the successful
# subqueries if that happens.
#   warnings.warn(_OVERSIZE_WARNING)
# ...

# %%
season_2023.head(10)
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 2432         CH 2023-10-01           89.0           -2.8           5.59
# 2525         FF 2023-10-01           96.9           -2.4            5.9
# 2631         CH 2023-10-01           90.0          -2.93           5.56
# 2727         ST 2023-10-01           82.2          -3.09           5.55
# 2748         CH 2023-10-01           89.2          -2.87           5.58
# 2902         FF 2023-10-01           96.2          -2.37           5.96
# 3076         CH 2023-10-01           88.2          -2.86           5.51
# 3204         FF 2023-10-01           95.7           -2.4            5.8
# 3329         ST 2023-10-01           79.4          -2.96           5.67
# 3459         ST 2023-10-01           82.9          -2.82           5.66
#
#           player_name  batter  pitcher     events      description  ...  \
# 2432  Robertson, Nick  677008   687798  field_out    hit_into_play  ...
# ...

# %% [markdown]
# ### 2024 Season

# %%
season_2024 = statcast(start_dt="2024-03-20", end_dt="2024-09-30")
# Out:
# This is a large query, it may take a moment to complete
# /Users/samuelgartenstein/anaconda3/lib/python3.11/site-packages/pybaseball/statcast.py:50: UserWarning:
# That's a nice request you got there. It'd be a shame if something were to happen to it.
# We strongly recommend that you enable caching before running this. It's as simple as `pybaseball.cache.enable()`.
# Since the Statcast requests can take a *really* long time to run, if something were to happen, like: a disconnect;
# gremlins; computer repair by associates of Rudy Giuliani; electromagnetic interference from metal trash cans; etc.;
# you could lose a lot of progress. Enabling caching will allow you to immediately recover all the successful
# subqueries if that happens.
#   warnings.warn(_OVERSIZE_WARNING)
# ...

# %%
season_2024.head(10)
# Out:
#     pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 200         FF 2024-09-30           97.4           -2.1           4.88
# 205         SL 2024-09-30           90.7          -2.14           5.06
# 211         SL 2024-09-30           91.1          -2.07           5.14
# 216         SL 2024-09-30           91.3          -2.05           5.07
# 221         SL 2024-09-30           89.1          -2.13           5.15
# 226         SL 2024-09-30           91.0           -2.0           5.21
# 231         SL 2024-09-30           90.7          -1.96           5.07
# 235         SL 2024-09-30           90.7          -2.08           5.14
# 240         FF 2024-09-30           98.0          -2.16           4.89
# 246         SL 2024-09-30           89.4          -2.16           5.21
#
#      player_name  batter  pitcher     events      description  ...  \
# 200  Díaz, Edwin  518595   621242  field_out    hit_into_play  ...
# ...

# %% [markdown]
# ### 2025 Season

# %%
season_2025 = statcast(start_dt="2025-03-18", end_dt="2025-09-28")
# Out:
# This is a large query, it may take a moment to complete
# /Users/samuelgartenstein/anaconda3/lib/python3.11/site-packages/pybaseball/statcast.py:50: UserWarning:
# That's a nice request you got there. It'd be a shame if something were to happen to it.
# We strongly recommend that you enable caching before running this. It's as simple as `pybaseball.cache.enable()`.
# Since the Statcast requests can take a *really* long time to run, if something were to happen, like: a disconnect;
# gremlins; computer repair by associates of Rudy Giuliani; electromagnetic interference from metal trash cans; etc.;
# you could lose a lot of progress. Enabling caching will allow you to immediately recover all the successful
# subqueries if that happens.
#   warnings.warn(_OVERSIZE_WARNING)
# ...

# %%
season_2025.head(10)
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 2011         FF 2025-09-28           95.7          -2.15           5.21
# 2093         FF 2025-09-28           95.1          -1.91            5.1
# 2155         FF 2025-09-28           95.4          -1.99           5.22
# 2264         SL 2025-09-28           84.8          -2.33           4.72
# 2358         SL 2025-09-28           85.3          -2.26           4.85
# 2460         SI 2025-09-28           95.2          -2.38           4.77
# 2549         FF 2025-09-28           95.3          -2.01           5.17
# 2589         SI 2025-09-28           95.0          -2.14           4.92
# 2789         FF 2025-09-28           95.5          -2.16           5.14
# 2851         FF 2025-09-28           94.9          -1.99           5.23
#
#          player_name  batter  pitcher     events      description  ...  \
# 2011  Weissert, Greg  678009   669711  field_out    hit_into_play  ...
# ...

# %% [markdown]
# ### Exporting Data

# %%
# Collect existing season DataFrames into a dict automatically
seasons = {
    year: df for year in range(2021, 2026)
    if (df := globals().get(f"season_{year}")) is not None
}

# Create subfolder: data/raw_season_data
outdir = Path("data") / "raw_season_data"
outdir.mkdir(parents=True, exist_ok=True)

for year, df in seasons.items():
    df.to_csv(outdir / f"season_{year}.csv", index=False, encoding="utf-8")
    print(f"[saved] {outdir / f'season_{year}.csv'}")
# Out:
# [saved] data/raw_season_data/season_2021.csv
# [saved] data/raw_season_data/season_2022.csv
# [saved] data/raw_season_data/season_2023.csv
# [saved] data/raw_season_data/season_2024.csv
# [saved] data/raw_season_data/season_2025.csv
